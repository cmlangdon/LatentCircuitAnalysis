# %%
import skorch
from datajoint_tables import *
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import gridspec
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
import warnings
warnings.filterwarnings('ignore')
from plotting import *
from sklearn.linear_model import Ridge
from tdr import *
from Regressor import *
from Trials import *
from RNN import *
from fit_dpca import *
# %matplotlib tk
# Out:
# Connecting langdon@pioneer.cshl.edu:3306

# %% [markdown]
# # Latent Circuit Mechanisms
# ## Figure: Recovering embedded circuit from high dimensional responses.
# * Hand constructed solution.

# %%
df = pd.DataFrame((Model() & 'connectivity="small"').proj('model_id', 'connectivity','lr','r2','l2_task','lambda_r','embedding').fetch())
df.sort_values(by=['l2_task'],ascending=True)
# Out:
#    model_id connectivity        lr  lambda_r        r2   l2_task  \
# 4  LZCI7OM8        small  0.001000  0.010000  0.934154  0.010291
# 7  YM6HTY2q        small  0.001000  0.010000  0.931087  0.010770
# 3  kLnNGynZ        small  0.001000  0.010000  0.930062  0.010930
# 1  A8nPJtAK        small  0.001000  0.010000  0.928447  0.011183
# 5  QFc1yvZV        small  0.001000  0.010000  0.926079  0.011553
# 0  9VuNrfPP        small  0.001000  0.010000  0.923112  0.012017
# 2  Bm8htmPw        small  0.001000  0.010000  0.921004  0.012346
# 6  yjYjpaHa        small  0.001000  0.010000  0.918385  0.012755
#
#                                            embedding
# 4  [[-0.40437853, -0.04380773, -0.022920363, 0.08...
# 7  [[-0.34601837, -0.00010275841, -0.009300046, -...
# 3  [[-0.27038664, 0.08736713, -0.1107955, 0.10244...
# 1  [[-0.36349434, -0.006123267, -0.053822346, -0....
# 5  [[-0.2686211, -0.08421017, 0.0339284, 0.079653...
# 0  [[-0.36259663, -0.020009577, 0.034330525, 0.02...
# 2  [[-0.333924, -0.042654026, 0.073205225, -0.047...
# 6  [[-0.32408744, 0.06871303, 0.03913643, -0.0363...

# %%
fig = plt.figure(figsize=(8,4))

gs0 = gridspec.GridSpec(2, 1, figure=fig,height_ratios=[5,4])

# Bottom row
gs01 = gridspec.GridSpecFromSubplotSpec(1, 4, subplot_spec=gs0[1])
ax1 = fig.add_subplot(gs01[0])
ax2 = fig.add_subplot(gs01[1])
ax3 = fig.add_subplot(gs01[2])
ax4 = fig.add_subplot(gs01[3])

# Top row
gs00 = gridspec.GridSpecFromSubplotSpec(1, 3, subplot_spec=gs0[0], width_ratios=[1,1,1],wspace=.5)

gs000 = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=gs00[0], width_ratios=[5,1],height_ratios=[5,1])
gs001 = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=gs00[1], width_ratios=[8,6],height_ratios=[8,2],wspace=0.1)
gs002 = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=gs00[2], width_ratios=[1,3,1],height_ratios=[1,3,1])


# network graph
ax5 = fig.add_subplot(gs00[0])


# solution
ax8 = fig.add_subplot(gs001[0, 0])

ax9 = fig.add_subplot(gs001[0, 1])
ax10 = fig.add_subplot(gs001[1, 0])

# decomposition of mechanism
ax11 = fig.add_subplot(gs002[0, 0])
ax12 = fig.add_subplot(gs002[0, 1])
ax13 = fig.add_subplot(gs002[0, 2])
ax14 = fig.add_subplot(gs002[1, 0])
ax15 = fig.add_subplot(gs002[1, 1])
ax16 = fig.add_subplot(gs002[1, 2])
ax17 = fig.add_subplot(gs002[2, 0])
ax18 = fig.add_subplot(gs002[2, 1])
ax19 = fig.add_subplot(gs002[2, 2])


q = np.eye(8)
q =  q[[0,2,4,6],:] - q[[1,3,5,7],:]
plot_sorted_projections("LZCI7OM8",q,ax1, ax2, ax3, ax4)

plot_model_parameters(Model(),"LZCI7OM8", ax8, ax9, ax10)

plot_circuit_decomposition(Model(), "LZCI7OM8", ax11, ax12, ax13, ax14, ax15, ax16, ax17, ax18, ax19)

plot_circuit_network(Model(), "LZCI7OM8", ax = ax5)
ax5.spines["top"].set_visible(False)

plt.savefig('/users/langdon/figures/circuitpaperfigures/Figure_1.png',dpi=1000, transparent=True)
plt.show()

# %% [markdown]
# ### Table of latent circuits

# %%
df=pd.DataFrame((LCA() & 'model_id="LZCI7OM8"' ).proj('model_id','lca_id','lr','max_epochs','valid_loss','w_error','q_error','r2_xqt').fetch())
df.sort_values(by=['valid_loss'],ascending=True)
# Out:
#      model_id    lca_id         lr  max_epochs  r2_xqt valid_loss   w_error  \
# 109  LZCI7OM8  GYVi2XCr  0.0010000        2500  0.0230     0.0587  0.284646
# 44   LZCI7OM8  AcMeEVWs  0.0010000        2500  0.0234     0.0592  0.227041
# 257  LZCI7OM8  vxHxkTFH  0.0010000        2500  0.0231     0.0598  0.195583
# 148  LZCI7OM8  LMPJ5BTO  0.0010000        3000  0.0233     0.0605  0.157719
# 150  LZCI7OM8  lptUSXuB  0.0010000        2500  0.0234     0.0606  0.221330
# ..        ...       ...        ...         ...     ...        ...       ...
# 31   LZCI7OM8  6w42XE1R  0.0010000        2500  0.0811     1.2979  1.652550
# 215  LZCI7OM8  RRLLwZOM  0.0010000        2500  0.0539     1.2988  1.367160
# 160  LZCI7OM8  MldD9hDp  0.0010000        3000  0.0965     1.3095  2.318900
# 228  LZCI7OM8  sTuxyK1w  0.0010000        2500  0.0731     1.3161  1.348760
# 273  LZCI7OM8  XoO7YZBO  0.0010000        1500  0.0790     1.3173  1.789330
#
#       q_error
# 109  0.061741
# 44   0.064082
# 257  0.057810
# 148  0.044576
# 150  0.058097
# ..        ...
# 31   1.027680
# 215  0.887072
# 160  1.132500
# 228  1.082810
# 273  1.237210
#
# [291 rows x 8 columns]

# %% [markdown]
# ### Figure

# %%
df = pd.DataFrame((LCA() & 'model_id="LZCI7OM8"' & 'valid_loss<.2'))
df = df.astype({'valid_loss': float})
plt.figure(figsize=(24,8))
plt.subplot(1,2,1)
sns.scatterplot(data=df, x="q_error", y="w_error", hue='valid_loss',size='valid_loss',sizes=(50,200))
#sns.set_style("whitegrid", {'axes.grid' : False})
plt.title('Validation')
plt.subplot(1,2,2)
sns.scatterplot(data=df, x="valid_loss", y="w_error", hue='q_error',size='q_error',sizes=(50,200))
#sns.set_style("whitegrid", {'axes.grid' : False})
plt.title('Sloppiness')
sns.set(font_scale = 2)

# %% [markdown]
# ## Figure Three: RNN Model
# * Train a large RNN model
# * Plot adjacency
# * Psychometrics

# %% [markdown]
# ### Table of large models

# %%
df = pd.DataFrame((Model() & 'connectivity="large"' & 'lambda_r=0.05').proj('model_id', 'connectivity','lr','r2','l2_task','lambda_r','lambda_o').fetch())
df.sort_values(by=['l2_task'],ascending=True)
# Out:
#     model_id connectivity        lr  lambda_r  lambda_o        r2   l2_task
# 10  LX7FtE5z        large  0.001000  0.050000  0.000000  0.986731  0.002074
# 16  x4MelZox        large  0.001000  0.050000  0.000000  0.985754  0.002226
# 13  PVZFfaOH        large  0.001000  0.050000  0.000000  0.985124  0.002325
# 9   LKHrNOom        large  0.001000  0.050000  0.000000  0.983039  0.002651
# 0   0wkbGOf3        large  0.001000  0.050000  0.000000  0.982938  0.002667
# 6   c2X1Yvsu        large  0.001000  0.050000  0.000000  0.982838  0.002682
# 1   3nRlEVeM        large  0.001000  0.050000  0.000000  0.980852  0.002993
# 12  o3Z6Uwpa        large  0.001000  0.050000  0.000000  0.979994  0.003127
# 7   CMwz5p1Z        large  0.001000  0.050000  1.000000  0.977836  0.003464
# 11  o0YwuNCo        large  0.001000  0.050000  1.000000  0.977095  0.003580
# 18  YYLT9fcD        large  0.001000  0.050000  1.000000  0.976459  0.003679
# 15  vZE32oJS        large  0.001000  0.050000  1.000000  0.975523  0.003825
# 14  rpE9tRDx        large  0.001000  0.050000  1.000000  0.971853  0.004399
# 2   5a8Myb4M        large  0.001000  0.050000  1.000000  0.971173  0.004505
# 8   dtp58apq        large  0.001000  0.050000  0.000000  0.968959  0.004851
# 3   6FEegJJ0        large  0.001000  0.050000  0.000000  0.913490  0.013520
# 5   C11pU214        large  0.001000  0.050000  1.000000  0.912727  0.013640
# 4   BeYHzdxr        large  0.001000  0.050000  1.000000  0.910092  0.014052
# 17  xv1kq0Xa        large  0.001000  0.050000  1.000000  0.905734  0.014733
# 19  ZUvRi43y        large  0.001000  0.050000  1.000000  0.905464  0.014775

# %% [markdown]
# ### Figure

# %%
plot_model("5a8Myb4M")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-00461418c3fd> in <module>
# ----> 1 plot_model("5a8Myb4M")
#
# ~/PycharmProjects/LatentCircuitAnalysis/plotting.py in plot_model(model_id)
#     849     plt.title('Output layer')
#     850
# --> 851     n_trials = trial_table.fetch().shape[0]
#     852     z = trial_table.fetch('output')
#     853     correct_choice = trial_table.fetch('correct_choice')
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/datajoint/fetch.py in __call__(self, offset, limit, order_by, format, as_dict, squeeze, download_path, *attrs)
#     185                 ret = return_values[0] if len(attrs) == 1 else return_values
#     186         else:  # fetch all attributes as a numpy.record_array or pandas.DataFrame
# --> 187             cur = self._expression.cursor(as_dict=as_dict, limit=limit, offset=offset, order_by=order_by)
#     188             heading = self._expression.heading
#     189             if as_dict:
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/datajoint/expression.py in cursor(self, offset, limit, order_by, as_dict)
#     573             sql += ' LIMIT %d' % limit + (' OFFSET %d' % offset if offset else "")
#     574         logger.debug(sql)
# --> 575         return self.connection.query(sql, as_dict=as_dict)
#     576
#     577
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/datajoint/connection.py in query(self, query, args, as_dict, suppress_warnings, reconnect)
#     213         cursor = self._conn.cursor(cursor=cursor_class)
#     214         try:
# --> 215             self._execute_query(cursor, query, args, cursor_class, suppress_warnings)
#     216         except errors.LostConnectionError:
#     217             if not reconnect:
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/datajoint/connection.py in _execute_query(cursor, query, args, cursor_class, suppress_warnings)
#     193                     # suppress all warnings arising from underlying SQL library
#     194                     warnings.simplefilter("ignore")
# --> 195                 cursor.execute(query, args)
#     196         except client.err.Error as err:
#     197             raise translate_query_error(err, query) from None
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1161                 self._read_load_local_packet(first_packet)
#    1162             else:
# -> 1163                 self._read_result_packet(first_packet)
#    1164         finally:
#    1165             self.connection = None
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/connections.py in _read_result_packet(self, first_packet)
#    1234         self.field_count = first_packet.read_length_encoded_integer()
#    1235         self._get_descriptions()
# -> 1236         self._read_rowdata_packet()
#    1237
#    1238     def _read_rowdata_packet_unbuffered(self):
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/connections.py in _read_rowdata_packet(self)
#    1268         rows = []
#    1269         while True:
# -> 1270             packet = self.connection._read_packet()
#    1271             if self._check_packet_is_eof(packet):
#    1272                 self.connection = None  # release reference to kill cyclic reference.
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     709             self._next_seq_id = (self._next_seq_id + 1) % 256
#     710
# --> 711             recv_data = self._read_bytes(bytes_to_read)
#     712             if DEBUG:
#     713                 dump_packet(recv_data)
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     730         while True:
#     731             try:
# --> 732                 data = self._rfile.read(num_bytes)
#     733                 break
#     734             except (IOError, OSError) as e:
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Figure 4: Latent Circuit
# * Fit latent circuit to above model
# * Plot latent circuit connectivity
#     * Network layout
#     * Adjacency matrix
#     * Q
#     * Sorted time series for latent neurons

# %% [markdown]
# ### Table of latent circuits

# %%
np.unique(LCA().proj('model_id').fetch('model_id'))
# Out:
# array(['5a8Myb4M', 'C11pU214', 'LX7FtE5z', 'MWhPjy4R', 'fdtFi2Nw'],
#       dtype=object)

# %%
lca_df = pd.DataFrame((LCA() & 'model_id="LX7FtE5z"' & 'max_epochs=2500' & 'max_diagonal_epoch=2500' & 'lr=.001' ).proj('model_id','lca_id','lr','max_epochs','r2_x','r2_xqt','r2_z','valid_loss','q', 'max_diagonal_epoch').fetch())
lca_df.sort_values(by=['valid_loss'],ascending=True)
# Out:
#     model_id    lca_id         lr  max_epochs  max_diagonal_epoch    r2_x  \
# 4   LX7FtE5z  bRKokhSP  0.0010000        2500                2500  0.0757
# 7   LX7FtE5z  dKj3UT1q  0.0010000        2500                2500  0.0750
# 26  LX7FtE5z  vZx147Bq  0.0010000        2500                2500  0.0787
# 18  LX7FtE5z  LzS7v2pj  0.0010000        2500                2500  0.0775
# 3   LX7FtE5z  7ASVH0HJ  0.0010000        2500                2500  0.0763
# 23  LX7FtE5z  QHQhNPQF  0.0010000        2500                2500  0.0778
# 28  LX7FtE5z  z7thZ4I5  0.0010000        2500                2500  0.0788
# 5   LX7FtE5z  cBnqAdgW  0.0010000        2500                2500  0.0780
# 29  LX7FtE5z  zfp4A1XR  0.0010000        2500                2500  0.0763
# 13  LX7FtE5z  hHvLtvd3  0.0010000        2500                2500  0.0796
# 9   LX7FtE5z  eD8l12ij  0.0010000        2500                2500  0.0769
# 1   LX7FtE5z  2Adz8CLg  0.0010000        2500                2500  0.0747
# 0   LX7FtE5z  0zazbOUv  0.0010000        2500                2500  0.0736
# 19  LX7FtE5z  ML1fuI0g  0.0010000        2500                2500  0.0747
# 16  LX7FtE5z  KGjhKZWI  0.0010000        2500                2500  0.0747
# 2   LX7FtE5z  65Zgetnz  0.0010000        2500                2500  0.0747
# 25  LX7FtE5z  VMubKNDp  0.0010000        2500                2500  0.0802
# 6   LX7FtE5z  d9v4Lw29  0.0010000        2500                2500  0.0829
# 17  LX7FtE5z  LTVqrYOM  0.0010000        2500                2500  0.0680
# 24  LX7FtE5z  V9xxusNQ  0.0010000        2500                2500  0.0758
# 10  LX7FtE5z  EQKsZUcC  0.0010000        2500                2500  0.0733
# 8   LX7FtE5z  dT0WtAEO  0.0010000        2500                2500  0.0820
# 27  LX7FtE5z  yWCwghHv  0.0010000        2500                2500  0.0723
# 15  LX7FtE5z  iW4r7hpj  0.0010000        2500                2500  0.0763
# 22  LX7FtE5z  nH8UP7WH  0.0010000        2500                2500  0.0668
# 11  LX7FtE5z  FGmXoD3g  0.0010000        2500                2500  0.1458
# 20  LX7FtE5z  MX8BfVrf  0.0010000        2500                2500  0.0915
# 21  LX7FtE5z  NA8Pv5IT  0.0010000        2500                2500  0.0791
# 14  LX7FtE5z  ig1zejb7  0.0010000        2500                2500  0.0787
# 12  LX7FtE5z  gBkGfNGx  0.0010000        2500                2500  0.0799
#
#     r2_xqt    r2_z valid_loss  \
# 4   0.0363  0.0322     0.1442
# 7   0.0386  0.0336     0.1472
# 26  0.0368  0.0321     0.1476
# 18  0.0378  0.0340     0.1494
# 3   0.0384  0.0356     0.1503
# 23  0.0393  0.0362     0.1533
# 28  0.0424  0.0360     0.1572
# 5   0.0427  0.0377     0.1584
# 29  0.0460  0.0393     0.1615
# 13  0.0448  0.0374     0.1618
# 9   0.0448  0.0445     0.1661
# 1   0.0490  0.0425     0.1662
# 0   0.0460  0.0484     0.1680
# 19  0.0471  0.0469     0.1687
# 16  0.0467  0.0478     0.1692
# 2   0.0482  0.0532     0.1762
# 25  0.0530  0.0432     0.1764
# 6   0.0471  0.0475     0.1775
# 17  0.0589  0.0534     0.1804
# 24  0.0489  0.0564     0.1810
# 10  0.0511  0.0571     0.1816
# 8   0.0581  0.0456     0.1856
# 27  0.0571  0.0616     0.1910
# 15  0.0859  0.0664     0.2286
# 22  0.0890  0.0914     0.2472
# 11  0.0645  0.0654     0.2756
# 20  0.1077  0.0984     0.2977
# 21  0.0457  1.1833     1.3082
# 14  0.0436  1.2244     1.3467
# 12  0.0681  1.2025     1.3505
#
#                                                     q
# 4   [[-0.001776725, 0.00621213, 0.0082151, -0.0038...
# 7   [[-0.01576075, -0.00036968663, 0.005680293, -0...
# 26  [[0.0021653473, -0.00033453293, 0.0060932785, ...
# 18  [[0.0027782917, -1.8276274e-05, 0.005027026, -...
# 3   [[0.0030919313, 0.00012229383, 0.0036124736, -...
# 23  [[0.0012272, -0.0015492737, 0.0049265027, -0.0...
# 28  [[-0.01530689, -0.0058804452, 0.0033901408, -0...
# 5   [[-0.01616764, -0.011388704, 0.003406126, -0.0...
# 29  [[-0.02007085, -0.012201369, 0.003440071, -0.0...
# 13  [[-0.00912863, 0.003938418, 0.0055787936, -0.0...
# 9   [[0.002443865, 0.006873302, 0.0041753445, -0.0...
# 1   [[0.0037802756, 0.0010058135, 0.005760759, -0....
# 0   [[-0.031046003, -0.013379991, 0.011283234, -0....
# 19  [[-0.00937672, -0.0028507076, 0.004609376, -0....
# 16  [[-0.033276036, -0.019125294, 0.0069493884, -0...
# 2   [[0.008757547, 0.00722152, 0.0061308146, -0.00...
# 25  [[-0.017754674, -0.0062036663, 0.0033720955, -...
# 6   [[-0.014878899, -0.0045596566, 0.0045121834, -...
# 17  [[-0.0372777, -0.013450548, 0.00096891075, -0....
# 24  [[0.00064885616, 0.0075003654, 0.001166312, -0...
# 10  [[-0.0062398016, 0.0049873814, 0.0054903403, -...
# 8   [[-0.005537778, 0.0020080116, 0.0056512803, -0...
# 27  [[-0.00920406, -0.011019854, -0.0030991286, -0...
# 15  [[-0.0039875507, 0.0020613782, 0.00027866662, ...
# 22  [[-0.010811314, -0.009792473, -0.0018491223, -...
# 11  [[-0.009540051, 0.0042023957, 0.0033908188, -0...
# 20  [[-0.003982842, 8.00658e-05, -0.0020226017, -0...
# 21  [[-0.031069815, -0.019223738, -0.002688177, 1....
# 14  [[-0.010150641, 0.0021864623, 0.0050151907, -0...
# 12  [[0.0017246902, -0.002753213, 0.0060247593, -0...

# %% [markdown]
# ### Figure

# %%
plot_latent_parameters(LCA(), "bRKokhSP")

# %%
plot_latent_parameters(LCA(), "dKj3UT1q")

# %%
plot_latent_parameters(LCA(), "vZx147Bq")

# %%
q = (LCA() & 'lca_id="gslTXoLF"').fetch1('q')
q =  q[[0,2,4,6],:] - q[[1,3,5,7],:]
plot_sorted_projections("LX7FtE5z", q)

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,3,1)
lca_table = LCA() & 'lca_id="mrhq0Ftn"'
model_table = Model() & 'model_id="6rV5JuQH"'
q = lca_table.fetch1('q')
w_in = model_table.fetch1('w_in')
w_out = model_table.fetch1('w_out')
w_ext = np.concatenate((w_in,w_out.T),axis=1)

sns.heatmap(q @ w_ext )
plt.xlabel(r'$W_{ext}$')
plt.ylabel(r'$Q$')
plt.title(r'$Q^T\cdot W_{ext}$')

plt.subplot(1,3,2)
Q = np.random.rand(150,150)
q = lca_table.fetch1('q')
Q[:8,:]=q
Q=Q.T
Q, _ = np.linalg.qr(Q)
Q[:,:8]= q.T
w_rec = model_table.fetch1('w_rec')
sns.heatmap((Q.T @ w_rec @ Q), center=0,cmap='coolwarm')
plt.title(r'$\hat{Q}^TW_{rec}\hat{Q}$')
plt.ylabel('Latent Neuron')
plt.xlabel('Latent Neuron')

plt.subplot(1,3,3)
sns.heatmap((Q.T @ w_rec @ Q)[:8,:8], center=0,cmap='coolwarm')
plt.title(r'$Q^TW_{rec}Q$')
plt.ylabel('Latent Neuron')
plt.xlabel('Latent Neuron')
# Out:
# ---------------------------------------------------------------------------
# DataJointError                            Traceback (most recent call last)
# <ipython-input-12-e9ecd1909df2> in <module>
#       3 lca_table = LCA() & 'lca_id="mrhq0Ftn"'
#       4 model_table = Model() & 'model_id="6rV5JuQH"'
# ----> 5 q = lca_table.fetch1('q')
#       6 w_in = model_table.fetch1('w_in')
#       7 w_out = model_table.fetch1('w_out')
#
# /opt/anaconda3/envs/LatentCircuitAnalysis/lib/python3.8/site-packages/datajoint/fetch.py in __call__(self, squeeze, download_path, *attrs)
#     245             result = self._expression.proj(*attributes).fetch(squeeze=squeeze, download_path=download_path, format="array")
#     246             if len(result) != 1:
# --> 247                 raise DataJointError('fetch1 should only return one tuple. %d tuples were found' % len(result))
#     248             return_values = tuple(
#     249                 next(to_dicts(result[self._expression.primary_key])) if is_key(attribute) else result[attribute][0]
#
# DataJointError: fetch1 should only return one tuple. 0 tuples were found

# %% [markdown]
# # Figure 5: Perturbations
# * Perturbations to confirm populations are behaviorally relevant.

# %% [markdown]
# ### Table of perturbations

# %%
ModelPerturbation()
# Out:
# *model_id    *perturbation_ type     direction     strength
# +----------+ +------------+ +------+ +-----------+ +----------+
# 5a8Myb4M     1Kb            lca      motion        0.100
# 5a8Myb4M     6E4            lca      motion        0.050
# 5a8Myb4M     eQL            tdr      motion        0.010
# 5a8Myb4M     Gp1            lr       motion        0.010
# 5a8Myb4M     HKx            lca      motion        0.010
# 5a8Myb4M     wzC            lr       motion        0.010
#  (Total: 6)

# %%
def plot_figure_five(trial_table,title):
    z = trial_table.fetch('output')
    motion_coh = trial_table.fetch('motion_coh')
    color_coh = trial_table.fetch('color_coh')
    context = trial_table.fetch('context')

    id_df = pd.DataFrame([])
    for i in range(900):
            data = {'motion_coh': motion_coh[i],
                    'color_coh': color_coh[i],
                    'choice': np.maximum(np.sign(z[i][-1,1] - z[i][-1,0]),0),
                    'context': context[i]}

            data = pd.DataFrame(data.items())
            data = data.transpose()
            data.columns = data.iloc[0]
            data = data.drop(data.index[[0]])
            id_df = id_df.append(data)
    motion_df = id_df[id_df['context']=="motion"]
    color_df = id_df[id_df['context']=="color"]

    motion_df = motion_df.groupby(['motion_coh', 'color_coh'])
    color_df = color_df.groupby(['motion_coh', 'color_coh'])
    motion_df = ((motion_df['choice'].apply(np.mean))).reset_index()
    color_df = ((color_df['choice'].apply(np.mean))).reset_index()

    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    sns.heatmap(motion_df.pivot(index='motion_coh', columns='color_coh', values='choice'), annot=True,vmin=0.5, vmax=1)
    plt.title('Motion context')

    plt.subplot(1,2,2)
    sns.heatmap(color_df.pivot(index='motion_coh', columns='color_coh', values='choice'), annot=True,vmin=0.5, vmax=1)
    plt.title('Color context')
    plt.suptitle(title)

# %% [markdown]
# ### Figure

# %%
plot_figure_five(PerturbationTrial() & 'perturbation_id="DzU"', 'LCA motion right perturbation')

# %%
plot_figure_five(PerturbationTrial() & 'perturbation_id="wzC"', 'TDR motion right perturbation')

# %% [markdown]
# # Figure 6: Interpretation
# * Interpretation of latent circuit
#     * What is Q?
#         * Plotting the matrix $Q^TW_\text{ext}$ shows that $Q\sim W_\text{ext}$
#     * Change of basis defined by $Q$
#         * Invariance and rank

# %% [markdown]
# # Figure 7: Orthogonality of inputs
# * Removing constraint on orthogonality of inputs
# * Correlation in inputs and outputs are inherited by latent circuit.

# %%
df = pd.DataFrame((Model() & 'connectivity="large"' & 'lambda_o=0').proj('model_id', 'connectivity','lr','r2','l2_task','lambda_r','lambda_o').fetch())
df.sort_values(by=['l2_task'],ascending=True).head(10)
# Out:
#     model_id connectivity        lr  lambda_r  lambda_o        r2   l2_task
# 17  sd5VQIR1        large  0.001000  0.100000  0.000000  0.987962  0.001881
# 5   AIadUz8Q        large  0.001000  0.100000  0.000000  0.987941  0.001885
# 18  WBALA5dy        large  0.001000  0.100000  0.000000  0.987262  0.001991
# 4   a9mJaece        large  0.001000  0.100000  0.000000  0.986925  0.002043
# 11  LX7FtE5z        large  0.001000  0.050000  0.000000  0.986731  0.002074
# 19  x4MelZox        large  0.001000  0.050000  0.000000  0.985754  0.002226
# 15  qcPhIcOy        large  0.001000  0.100000  0.000000  0.985493  0.002267
# 13  PVZFfaOH        large  0.001000  0.050000  0.000000  0.985124  0.002325
# 10  LKHrNOom        large  0.001000  0.050000  0.000000  0.983039  0.002651
# 0   0wkbGOf3        large  0.001000  0.050000  0.000000  0.982938  0.002667

# %% [markdown]
# ### Panels A, B and C

# %%
plot_model("LX7FtE5z")

# %% [markdown]
# ### Panel D

# %%
model_table = Model() & 'model_id="LX7FtE5z"'
w_in = model_table.fetch1('w_in')
w_out = model_table.fetch1('w_out')
w_ext = np.concatenate((w_in,w_out.T),axis=1)
w_ext = w_ext / np.linalg.norm(w_ext,axis=0)
sns.heatmap(w_ext.T@w_ext) 
plt.xlabel(r'$W_{ext}$')
plt.ylabel(r'$W_{ext}$')
plt.title(r'$W_{ext}^TW_{ext}$')
# Out:
# Text(0.5, 1.0, '$W_{ext}^TW_{ext}$')

# %%
lca_df = pd.DataFrame((LCA() & 'model_id="LX7FtE5z"' & 'lr=.01' ).proj('model_id','lca_id','lr','max_epochs','valid_loss').fetch())
lca_df.sort_values(by=['valid_loss'],ascending=True)
# Out:
#     model_id    lca_id         lr  max_epochs valid_loss
# 81  LX7FtE5z  s7tyC43O  0.0100000        2500     0.0987
# 43  LX7FtE5z  Hw0ieI6q  0.0100000        2500     0.0988
# 80  LX7FtE5z  rZUTbQj9  0.0100000        2500     0.0988
# 71  LX7FtE5z  pNZtQqQZ  0.0100000        2500     0.0988
# 48  LX7FtE5z  IGz0HTy2  0.0100000        2500     0.0991
# ..       ...       ...        ...         ...        ...
# 23  LX7FtE5z  ccvG4eIB  0.0100000        2500     0.6010
# 79  LX7FtE5z  rz3cRIkC  0.0100000        2500     0.6167
# 74  LX7FtE5z  qn6SudSU  0.0100000        2500     0.6191
# 99  LX7FtE5z  yAvp9WNw  0.0100000        2500     0.6221
# 22  LX7FtE5z  bUOtQYWA  0.0100000        2500     0.6465
#
# [105 rows x 5 columns]

# %%
plot_latent_parameters(LCA(), "s7tyC43O")

# %%
plot_latent_parameters(LCA(), "Hw0ieI6q")

# %%
plot_latent_parameters(LCA(), "rZUTbQj9")

# %%
plot_latent_parameters(LCA(), "pNZtQqQZ")

# %%
model_table = Model() & 'model_id="LX7FtE5z"'
w_in = model_table.fetch1('w_in')
w_out = model_table.fetch1('w_out')
w_ext = np.concatenate((w_in,w_out.T),axis=1)
w_ext = w_ext / np.linalg.norm(w_ext,axis=0)
q = (LCA() & 'lca_id="rZUTbQj9"').fetch1('q')
sns.heatmap(q @ w_ext) 
plt.xlabel(r'$W_{ext}$')
plt.ylabel(r'$W_{ext}$')
plt.title(r'$W_{ext}^TW_{ext}$')
# Out:
# Text(0.5, 1.0, '$W_{ext}^TW_{ext}$')

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,3,1)
lca_table = LCA() & 'lca_id="yxa273q2"'
model_table = Model() & 'model_id="LX7FtE5z"'
q = lca_table.fetch1('q')
w_in = model_table.fetch1('w_in')
w_out = model_table.fetch1('w_out')
w_ext = np.concatenate((w_in,w_out.T),axis=1)

sns.heatmap(q @ w_ext )
plt.xlabel(r'$W_{ext}$')
plt.ylabel(r'$Q$')
plt.title(r'$Q^T\cdot W_{ext}$')

plt.subplot(1,3,2)
Q = np.random.rand(150,150)
q = lca_table.fetch1('q')
Q[:8,:]=q
Q=Q.T
Q, _ = np.linalg.qr(Q)
Q[:,:8]= q.T
w_rec = model_table.fetch1('w_rec')
sns.heatmap((Q.T @ w_rec @ Q), center=0,cmap='coolwarm')
plt.title(r'$\hat{Q}^TW_{rec}\hat{Q}$')
plt.ylabel('Latent Neuron')
plt.xlabel('Latent Neuron')

plt.subplot(1,3,3)
sns.heatmap((Q.T @ w_rec @ Q)[:8,:8], center=0,cmap='coolwarm')
plt.title(r'$Q^TW_{rec}Q$')
plt.ylabel('Latent Neuron')
plt.xlabel('Latent Neuron')
# Out:
# Text(0.5, 15.0, 'Latent Neuron')

# %%
sns.heatmap(q)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=np.ravel(q),y=np.ravel(w_ext))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Comparison to demixing
# We show that demixing methods are able find projections which show minimal modulation of stimuli in networks which utilize a known suppression mechanism. This is possible by trading variance for demixing and finding projections which are not behaviorally relevant.

# %% [markdown]
# ## Comparison to Linear Regression
# * We compare two types of regression:
# $$ \mathbf{y} = \beta \mathbf{x}$$
# and
# \begin{align*}
# \mathbf{y} &= \beta \mathbf{x}\\
# \dot{\mathbf{x}} &= \phi(\mathbf{x})
# \end{align*}
# * **Figure:** Comparison of motion axes. Regression shows less suppression.
# * Explanation: If we decompose the squared error:
# \begin{align*}
# \Vert \mathbf{y} - \beta\mathbf{x} \Vert^2 &= \Vert \mathbf{y}- \beta\mathbf{x} +\beta\beta^T\mathbf{y}- \beta\beta^T\mathbf{y} \Vert ^2 \\
# &= \Vert \mathbf{y} - \beta\beta^T\mathbf{y} \Vert ^2 + \Vert \beta\beta^T\mathbf{y} - \beta^T\beta\mathbf{x} \Vert ^2
# \end{align*}
# the second term
# $$\Vert \beta\beta^T\mathbf{y} - \beta^T\beta\mathbf{x} \Vert ^2 = \Vert\beta\Vert^2\Vert\beta^T\mathbf{y} - \mathbf{x} \Vert ^2$$
# corresponds to the error between the latent variable and the regressor.

# %%
Regression()
# Out:
# *model_id    *orthogonal    *active    q
# +----------+ +------------+ +--------+ +--------+
# 5a8Myb4M     True           True       =BLOB=
# 5a8Myb4M     True           False      =BLOB=
# 5a8Myb4M     False          False      =BLOB=
#  (Total: 3)

# %%
q = (LCA() & 'lca_id="DykEOu7Y"').fetch1('q')
q_lca =  q[[0,2,4,6],:] - q[[1,3,5,7],:]
plot_sorted_projections("5a8Myb4M",q_lca)

# %%
q_reg = (Regression() & 'model_id="5a8Myb4M"' & 'orthogonal="True"' & 'active="False"').fetch1('q')
plot_sorted_projections("5a8Myb4M", q_reg)

# %%
b_tdr,q_tdr = tdr("5a8Myb4M")
plot_sorted_projections("5a8Myb4M", b)
# Out:
# (4, 1080)

# %%
model_table = Model() & 'model_id="5a8Myb4M"'
w_in = model_table.fetch1('w_in')
w_out = model_table.fetch1('w_out')
w_ext = np.concatenate((w_in,w_out.T),axis=1)
w_ext = w_ext / np.linalg.norm(w_ext,axis=0)
w_ext = w_ext[:,[0,2,4,6]] - w_ext[:,[1,3,5,7]]

sns.set(font_scale = 2)
plt.figure(figsize=(28,4))

plt.subplot(1,4,1)
q_lca = q_lca / np.linalg.norm(q_lca,axis=1, keepdims=True)
sns.heatmap(q_lca @ w_ext) 
plt.xlabel(r'$W_{ext}$')
plt.ylabel(r'$Q_{lca}$')
plt.title('LCA')


plt.subplot(1,4,2)
sns.heatmap(q_reg @ w_ext) 
plt.xlabel(r'$W_{ext}$')
plt.ylabel(r'$Q_{reg}$')
plt.title('Orthgonal Regression')

plt.subplot(1,4,3)
sns.heatmap(q_tdr.T @ w_ext) 
plt.xlabel(r'$W_{ext}$')
plt.ylabel(r'$Q_{tdr}$')
plt.title('TDR (orthogonal)')

plt.subplot(1,4,4)
b_tdr = b_tdr / np.linalg.norm(b_tdr,axis=1, keepdims=True)
sns.heatmap(b_tdr @ w_ext) 
plt.xlabel(r'$W_{ext}$')
plt.ylabel(r'$B_{tdr}$')
plt.title('TDR')
# Out:
# Text(0.5, 1.0, 'TDR')

# %% [markdown]
# # Supplementary Figures

# %%
q = fit_dpca("5a8Myb4M")
# Out:
# You chose to determine the regularization parameter automatically. This can
#                     take substantial time and grows linearly with the number of crossvalidation
#                     folds. The latter can be set by changing self.n_trials (default = 3). Similarly,
#                     use self.protect to set the list of axes that are not supposed to get to get shuffled
#                     (e.g. upon splitting the data into test- and training, time-points should always
#                     be drawn from the same trial, i.e. self.protect = ['t']). This can significantly
#                     speed up the code.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-433ca8197b9a> in <module>
# ----> 1 q = fit_dpca("5a8Myb4M")
#
# ~/PycharmProjects/LatentCircuitAnalysis/fit_dpca.py in fit_dpca(model_id)
#      38     dpca.protect = ['t']
#      39
# ---> 40     q = np.concatenate((dpca.D['r'][:, 0, None], dpca.D['m'][:, 0, None], dpca.D['c'][:, 0, None], dpca.D['m'][:, 0, None]),axis=1)
#      41
#      42     return q
#
# AttributeError: 'dPCA' object has no attribute 'D'
